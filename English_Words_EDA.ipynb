# %% [markdown]
# <a href="https://colab.research.google.com/github/Saeswar/AI-ML-AVANTHI-SAESWAR/blob/main/English_Words_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import the Pandas library

# %%
import pandas as pd

# %% [markdown]
# Read the txt file into a dataframe

# %%
df = pd.read_csv('/content/unix-words.txt')
df
# Out:
#                  A
# 0                a
# 1               aa
# 2              aal
# 3            aalii
# 4              aam
# ...            ...
# 235880      zythem
# 235881      Zythia
# 235882      zythum
# 235883     Zyzomys
# 235884  Zyzzogeton
#
# [235885 rows x 1 columns]

# %% [markdown]
# Display the first 10 rows of the dataframe

# %%
df.head(10)
# Out:
#           A
# 0         a
# 1        aa
# 2       aal
# 3     aalii
# 4       aam
# 5      Aani
# 6  aardvark
# 7  aardwolf
# 8     Aaron
# 9   Aaronic

# %% [markdown]
# Change the column name 'A' to the words

# %%
df.rename(columns={'A':'Words'})
# Out:
#              Words
# 0                a
# 1               aa
# 2              aal
# 3            aalii
# 4              aam
# ...            ...
# 235880      zythem
# 235881      Zythia
# 235882      zythum
# 235883     Zyzomys
# 235884  Zyzzogeton
#
# [235885 rows x 1 columns]

# %%
df = df.rename(columns={'A':'Words'})

# %% [markdown]
# Add character count of each word as another column in the dataframe

# %%
df['Words'] = df['Words'].fillna('')
df['Charcount'] = df['Words'].apply(len)
df
# Out:
#              Words  Charcount
# 0                a          1
# 1               aa          2
# 2              aal          3
# 3            aalii          5
# 4              aam          3
# ...            ...        ...
# 235880      zythem          6
# 235881      Zythia          6
# 235882      zythum          6
# 235883     Zyzomys          7
# 235884  Zyzzogeton         10
#
# [235885 rows x 2 columns]

# %% [markdown]
# Add a column called value which is the sum of the numerical positions of the alphabets in the word
# (Ex: aah = 1 + 1 + 8 = 10)

# %%
def summing(word):
  sum = 0
  word.lower()
  for char in word:
    position = ord(char) - 96
    sum += position
  return sum

df['Values'] = df['Words'].apply(summing)
df
# Out:
#              Words  Charcount  Values
# 0                a          1       1
# 1               aa          2       2
# 2              aal          3      14
# 3            aalii          5      32
# 4              aam          3      15
# ...            ...        ...     ...
# 235880      zythem          6      97
# 235881      Zythia          6      57
# 235882      zythum          6     113
# 235883     Zyzomys          7     117
# 235884  Zyzzogeton         10     147
#
# [235885 rows x 3 columns]

# %%
df.head()
# Out:
#    Words  Charcount  Values
# 0      a          1       1
# 1     aa          2       2
# 2    aal          3      14
# 3  aalii          5      32
# 4    aam          3      15

# %% [markdown]
# Write a command to find the number of items in the dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235885 entries, 0 to 235884
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Words      235885 non-null  object
#  1   Charcount  235885 non-null  int64
#  2   Values     235885 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 5.4+ MB

# %% [markdown]
# Set the words as the index of the dataframe

# %%
df.set_index('Words')
# Out:
#             Charcount  Values
# Words
# a                   1       1
# aa                  2       2
# aal                 3      14
# aalii               5      32
# aam                 3      15
# ...               ...     ...
# zythem              6      97
# Zythia              6      57
# zythum              6     113
# Zyzomys             7     117
# Zyzzogeton         10     147
#
# [235885 rows x 2 columns]

# %% [markdown]
# What is the value of the word 'Acanthomeridae'?

# %%
df.loc[df['Words'] == 'Acanthomeridae','Values']
# Out:
# 762    85
# Name: Values, dtype: int64

# %% [markdown]
# What is the highest possible value for a word?

# %%
df.max()
# Out:
# Words        zythum
# Charcount        24
# Values          328
# dtype: object

# %% [markdown]
# What is the highest possible length of a word

# %%
df['Charcount'].max()
# Out:
# 24

# %% [markdown]
# What is the value of the word with Value '317'

# %%
df.loc[df['Values'] == 317]
# Out:
#                            Words  Charcount  Values
# 203040  thyroparathyroidectomize         24     317

# %% [markdown]
# What is the most common value?

# %%
df.mode()
# Out:
#   Words  Charcount  Values
# 0                9     102

# %%
df.value_counts()
# Out:
# Words             Charcount  Values
#                   0          0         2
# polyphote         9          132       1
# polyphyletic      12         166       1
# polyphyletically  16         216       1
# polyphylety       11         179       1
#                                       ..
# embryotrophic     13         167       1
# embryotrophy      12         180       1
# embryous          8          118       1
# embryulcia        10         109       1
# zythum            6          113       1
# Length: 235884, dtype: int64

# %%
df['Values'].value_counts().head()
# Out:
# 102    2218
# 107    2194
# 100    2185
# 108    2184
# 115    2171
# Name: Values, dtype: int64

# %% [markdown]
# What is the shortest word with the value of 107

# %%
df.loc[df['Values'] == 107].min()
# Out:
# Words        Agriochoerus
# Charcount               5
# Values                107
# dtype: object

# %% [markdown]
# Create a new column 'Ratio' such that ratio = value/char count

# %%
df['ratio'] = df['Values']/df['Charcount']
df
# Out:
#              Words  Charcount  Values value/charcount      ratio
# 0                a          1       1           ratio   1.000000
# 1               aa          2       2           ratio   1.000000
# 2              aal          3      14           ratio   4.666667
# 3            aalii          5      32           ratio   6.400000
# 4              aam          3      15           ratio   5.000000
# ...            ...        ...     ...             ...        ...
# 235880      zythem          6      97           ratio  16.166667
# 235881      Zythia          6      57           ratio   9.500000
# 235882      zythum          6     113           ratio  18.833333
# 235883     Zyzomys          7     117           ratio  16.714286
# 235884  Zyzzogeton         10     147           ratio  14.700000
#
# [235885 rows x 5 columns]

# %% [markdown]
# What is the maximum value of ratio?

# %%
df['ratio'].max()
# Out:
# 26.0

# %% [markdown]
# What is the word with the highest ratio

# %%
df.loc[df['ratio']== 26]
# Out:
#        Words  Charcount  Values value/charcount  ratio
# 234937     z          1      26           ratio   26.0

# %%
  df.loc[df['ratio'] == df['ratio'].max()]
# Out:
#        Words  Charcount  Values value/charcount  ratio
# 234937     z          1      26           ratio   26.0

# %%
df.sort_values('Values')
# Out:
#                            Words  Charcount  Values value/charcount      ratio
# 17095                          B          1     -30           ratio -30.000000
# 28165                          C          1     -29           ratio -29.000000
# 14                            Ab          2     -29           ratio -14.500000
# 48066                          D          1     -28           ratio -28.000000
# 58962                          E          1     -27           ratio -27.000000
# ...                          ...        ...     ...             ...        ...
# 104217    laparocolpohysterotomy         22     307           ratio  13.954545
# 160718    pyopneumocholecystitis         22     307           ratio  13.954545
# 225854    ureterocystanastomosis         22     314           ratio  14.272727
# 203040  thyroparathyroidectomize         24     317           ratio  13.208333
# 48117     dacryocystosyringotomy         22     328           ratio  14.909091
#
# [235885 rows x 5 columns]

# %% [markdown]
# How many words have the ratio of 10

# %%
df['ratio'].value_counts()
# Out:
#  12.000000    4334
#  11.000000    4117
#  13.000000    3716
#  10.000000    3159
#  14.000000    2537
#               ...
# -22.000000       1
# -1.272727        1
# -21.000000       1
# -20.000000       1
#  26.000000       1
# Name: ratio, Length: 1780, dtype: int64

# %%
df.loc[df['ratio']==10]
# Out:
#               Words  Charcount  Values value/charcount  ratio
# 7          aardwolf          8      80           ratio   10.0
# 31         abaculus          8      80           ratio   10.0
# 198        abetment          8      80           ratio   10.0
# 329            ably          4      40           ratio   10.0
# 403        abounder          8      80           ratio   10.0
# ...             ...        ...     ...             ...    ...
# 235406      Zolaist          7      70           ratio   10.0
# 235467  zoochemical         11     110           ratio   10.0
# 235735     zwieback          8      80           ratio   10.0
# 235744    Zygadenus          9      90           ratio   10.0
# 235877     Zyrenian          8      80           ratio   10.0
#
# [3159 rows x 5 columns]

# %% [markdown]
# What is the maximum value of all words with ratio as 10

# %%
  df.loc[df['ratio'] == 10].max()
# Out:
# Words              zwieback
# Charcount                21
# Values                  210
# value/charcount       ratio
# ratio                  10.0
# dtype: object

# %%
df.query("ratio == 10").max()
# Out:
# Words              zwieback
# Charcount                21
# Values                  210
# value/charcount       ratio
# ratio                  10.0
# dtype: object

# %% [markdown]
# Of all the words with the value of 260, what has the loswest character count?

# %%
df.query('Values == 260').min()
# Out:
# Words              chromophotolithograph
# Charcount                             17
# Values                               260
# value/charcount                    ratio
# ratio                          11.818182
# dtype: object

# %%
df.describe()
# Out:
#            Charcount         Values          ratio
# count  235885.000000  235885.000000  235883.000000
# mean        9.569133     108.969218      11.256517
# std         2.927375      43.525601       2.766208
# min         0.000000     -30.000000     -30.000000
# 25%         8.000000      78.000000       9.846154
# 50%         9.000000     107.000000      11.545455
# 75%        11.000000     137.000000      13.000000
# max        24.000000     328.000000      26.000000
